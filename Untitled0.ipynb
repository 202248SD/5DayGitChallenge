# %% [markdown]
# <a href="https://colab.research.google.com/github/202248SD/5DayGitChallenge/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://universe.roboflow.com/ds/18ffteoDY0?key=2tIts2EfYk
# !unzip '18ffteoDY0?key=2tIts2EfYk'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/labels/n02112706_220_jpg.rf.92aba4462276528ff9d85c566a86fa95.txt
#   inflating: train/labels/n02112706_2269_jpg.rf.d134d2640b99c26614f88d7ab0d84c8e.txt
#   inflating: train/labels/n02112706_231_jpg.rf.f138c78c3ffd6fbca958f53b66dc5321.txt
#   inflating: train/labels/n02112706_235_jpg.rf.5c97347524d20b163949628e2efd06d3.txt
#   inflating: train/labels/n02112706_237_jpg.rf.16b4ac30aaf568bb6a909e8e9e9d7ada.txt
#   inflating: train/labels/n02112706_2390_jpg.rf.711301fdcb779f2a94a898bb5f696375.txt
#   inflating: train/labels/n02112706_2441_jpg.rf.ee62e219c1d90c8554f21a8186dba1c2.txt
#   inflating: train/labels/n02112706_2448_jpg.rf.6339a1afb91524e1aa099de75574a7c2.txt
#   inflating: train/labels/n02112706_2467_jpg.rf.7f7d7e1767e6df0134398c3dc3a0ca4b.txt
#   inflating: train/labels/n02112706_256_jpg.rf.b4b193bee760775658fb0718818db319.txt
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16634, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 16634 (delta 70), reused 105 (delta 47), pack-reused 16459
# Receiving objects: 100% (16634/16634), 15.29 MiB | 13.29 MiB/s, done.
# Resolving deltas: 100% (11376/11376), done.

# %%
# !python yolov5/train.py --img 640 --batch 32 --epochs 4 --data data.yaml --weights yolov5s.pt
# Out:
# 2024-06-18 08:58:34.817855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-18 08:58:34.817904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-18 08:58:34.819319: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !apt-get install zip

# !zip -r /content/yolov5/runs/train/exp2.zip /content/yolov5/runs/train/exp2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# zip is already the newest version (3.0-12build2).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/train_batch2.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp2/val_batch1_pred.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/val_batch1_labels.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/R_curve.png (deflated 25%)
#   adding: content/yolov5/runs/train/exp2/events.out.tfevents.1718701117.10ae5241e78b.2819.0 (deflated 30%)
#   adding: content/yolov5/runs/train/exp2/results.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp2/P_curve.png (deflated 22%)
#   adding: content/yolov5/runs/train/exp2/.ipynb_checkpoints/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/PR_curve.png (deflated 19%)
# ...

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/exp2.zip")
